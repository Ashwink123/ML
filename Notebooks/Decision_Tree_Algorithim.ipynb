# %%
import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as pltb

# %%
heart = pd.read_csv('/mnt/c/Users/Ashwin/Documents/Ash/Projects/ML/Data/heart_v2.csv')
heart.head()
# Out:
#    age  sex   BP  cholestrol  heart disease
# 0   70    1  130         322              1
# 1   67    0  115         564              0
# 2   57    1  124         261              1
# 3   64    1  128         263              0
# 4   74    0  120         269              0

# %%
heart['heart disease'].value_counts()
# Out:
# 0    150
# 1    120
# Name: heart disease, dtype: int64

# %%
x = heart.drop('heart disease',axis=1)
y = heart['heart disease']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.7,random_state=100)
x_train.shape,x_test.shape
# Out:
# ((189, 4), (81, 4))

# %%
from IPython.display import Image
from six import StringIO
from sklearn.tree import export_graphviz

# %%
import pydotplus,graphviz

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(max_depth=3)

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(60,30))
plot_tree(dt, feature_names = x.columns,class_names=['No Disease', "Disease"],filled=True)
# Out:
# [Text(0.5, 0.875, 'age <= 54.5\ngini = 0.494\nsamples = 189\nvalue = [105, 84]\nclass = No Disease'),
#  Text(0.25, 0.625, 'sex <= 0.5\ngini = 0.403\nsamples = 93\nvalue = [67, 26]\nclass = No Disease'),
#  Text(0.125, 0.375, 'cholestrol <= 304.5\ngini = 0.117\nsamples = 32\nvalue = [30, 2]\nclass = No Disease'),
#  Text(0.0625, 0.125, 'gini = 0.0\nsamples = 29\nvalue = [29, 0]\nclass = No Disease'),
#  Text(0.1875, 0.125, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = Disease'),
#  Text(0.375, 0.375, 'age <= 40.5\ngini = 0.477\nsamples = 61\nvalue = [37, 24]\nclass = No Disease'),
#  Text(0.3125, 0.125, 'gini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = Disease'),
#  Text(0.4375, 0.125, 'gini = 0.452\nsamples = 55\nvalue = [36, 19]\nclass = No Disease'),
#  Text(0.75, 0.625, 'BP <= 122.0\ngini = 0.478\nsamples = 96\nvalue = [38, 58]\nclass = Disease'),
#  Text(0.625, 0.375, 'sex <= 0.5\ngini = 0.453\nsamples = 26\nvalue = [17, 9]\nclass = No Disease'),
#  Text(0.5625, 0.125, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = No Disease'),
#  Text(0.6875, 0.125, 'gini = 0.498\nsamples = 17\nvalue = [8, 9]\nclass = Disease'),
#  Text(0.875, 0.375, 'cholestrol <= 247.0\ngini = 0.42\nsamples = 70\nvalue = [21, 49]\nclass = Disease'),
#  Text(0.8125, 0.125, 'gini = 0.499\nsamples = 25\nvalue = [12, 13]\nclass = Disease'),
#  Text(0.9375, 0.125, 'gini = 0.32\nsamples = 45\nvalue = [9, 36]\nclass = Disease')]
